# %%
import pandas as pd

values_df = pd.read_csv("Pokemon.csv", delimiter=',')

print('\nGeneral information about the table data')
print(values_df.info())

print('\nTable data output')
print(values_df)

print('\nColumn names output')
print(values_df.columns)

print('\nNumber of missing values')
print(values_df.isnull().sum())

print(f'\nNumber of duplicate rows: {values_df.duplicated().sum()}')
# Out:
# General information about the table data
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1211 entries, 0 to 1210
# Data columns (total 32 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Pokemon               1211 non-null   object
#  1   Type                  1211 non-null   object
#  2   Species               1211 non-null   object
#  3   Height                1211 non-null   object
#  4   Weight                1211 non-null   object
#  5   Abilities             1211 non-null   object
#  6   EV Yield              1211 non-null   object
#  7   Catch Rate            1211 non-null   object
#  8   Base Friendship       1211 non-null   object
#  9   Base Exp              1211 non-null   object
#  10  Growth Rate           1211 non-null   object
#  11  Egg Groups            1211 non-null   object
#  12  Gender                1211 non-null   object
#  13  Egg Cycles            1211 non-null   object
#  14  HP Base               1211 non-null   int64
#  15  HP Min                1211 non-null   int64
#  16  HP Max                1211 non-null   int64
#  17  Attack Base           1211 non-null   int64
#  18  Attack Min            1211 non-null   int64
#  19  Attack Max            1211 non-null   int64
#  20  Defense Base          1211 non-null   int64
#  21  Defense Min           1211 non-null   int64
#  22  Defense Max           1211 non-null   int64
#  23  Special Attack Base   1211 non-null   int64
#  24  Special Attack Min    1211 non-null   int64
#  25  Special Attack Max    1211 non-null   int64
#  26  Special Defense Base  1211 non-null   int64
#  27  Special Defense Min   1211 non-null   int64
#  28  Special Defense Max   1211 non-null   int64
#  29  Speed Base            1211 non-null   int64
#  30  Speed Min             1211 non-null   int64
#  31  Speed Max             1211 non-null   int64
# dtypes: int64(18), object(14)
# memory usage: 302.9+ KB
# None
#
# Table data output
#                      Pokemon            Type             Species  \
# 0                  Abomasnow      Grass, Ice  Frost Tree Pokémon
# 1             Mega Abomasnow      Grass, Ice  Frost Tree Pokémon
# 2                       Abra         Psychic         Psi Pokémon
# 3                      Absol            Dark    Disaster Pokémon
# 4                 Mega Absol            Dark    Disaster Pokémon
# ...                      ...             ...                 ...
# 1206                   Zubat  Poison, Flying         Bat Pokémon
# 1207                Zweilous    Dark, Dragon     Hostile Pokémon
# 1208       Zygarde 50% Forme  Dragon, Ground       Order Pokémon
# 1209       Zygarde 10% Forme  Dragon, Ground       Order Pokémon
# 1210  Zygarde Complete Forme  Dragon, Ground       Order Pokémon
#
#               Height                 Weight  \
# 0      2.2 m (7′03″)   135.5 kg (298.7 lbs)
# 1      2.7 m (8′10″)   185.0 kg (407.9 lbs)
# 2      0.9 m (2′11″)     19.5 kg (43.0 lbs)
# 3      1.2 m (3′11″)    47.0 kg (103.6 lbs)
# 4      1.2 m (3′11″)    49.0 kg (108.0 lbs)
# ...              ...                    ...
# 1206   0.8 m (2′07″)      7.5 kg (16.5 lbs)
# 1207   1.4 m (4′07″)    50.0 kg (110.2 lbs)
# 1208  5.0 m (16′05″)   305.0 kg (672.4 lbs)
# 1209   1.2 m (3′11″)     33.5 kg (73.9 lbs)
# 1210  4.5 m (14′09″)  610.0 kg (1344.8 lbs)
#
#                                               Abilities             EV Yield  \
# 0          1. Snow Warning, Soundproof (hidden ability)  1 Attack, 1 Sp. Atk
# 1                                       1. Snow Warning  1 Attack, 1 Sp. Atk
# 2     1. Synchronize, 2. Inner Focus, Magic Guard (h...            1 Sp. Atk
# 3     1. Pressure, 2. Super Luck, Justified (hidden ...             2 Attack
# 4                                       1. Magic Bounce             2 Attack
# ...                                                 ...                  ...
# 1206       1. Inner Focus, Infiltrator (hidden ability)              1 Speed
# 1207                                          1. Hustle             2 Attack
# 1208                  1. Aura Break, 2. Power Construct                 3 HP
# 1209                  1. Aura Break, 2. Power Construct                 3 HP
# 1210                                 1. Power Construct                 3 HP
#
#                               Catch Rate         Base Friendship Base Exp  \
# 0       60 (7.8% with PokéBall, full HP)             50 (normal)      173
# 1       60 (7.8% with PokéBall, full HP)             50 (normal)      208
# 2     200 (26.1% with PokéBall, full HP)             50 (normal)       62
# 3       30 (3.9% with PokéBall, full HP)  35 (lower than normal)      163
# 4       30 (3.9% with PokéBall, full HP)  35 (lower than normal)      198
# ...                                  ...                     ...      ...
# 1206  255 (33.3% with PokéBall, full HP)             50 (normal)       49
# 1207    45 (5.9% with PokéBall, full HP)  35 (lower than normal)      147
# 1208     3 (0.4% with PokéBall, full HP)   0 (lower than normal)      270
# 1209     3 (0.4% with PokéBall, full HP)   0 (lower than normal)      219
# 1210     3 (0.4% with PokéBall, full HP)   0 (lower than normal)      319
#
#       ... Defense Max Special Attack Base Special Attack Min  \
# 0     ...         273                  92                170
# 1     ...         339                 132                242
# 2     ...         141                 105                193
# 3     ...         240                  75                139
# 4     ...         240                 115                211
# ...   ...         ...                 ...                ...
# 1206  ...         185                  30                 58
# 1207  ...         262                  65                121
# 1208  ...         375                  81                150
# 1209  ...         265                  61                114
# 1210  ...         375                  91                168
#
#      Special Attack Max  Special Defense Base  Special Defense Min  \
# 0                   311                    85                  157
# 1                   399                   105                  193
# 2                   339                    55                  103
# 3                   273                    60                  112
# 4                   361                    60                  112
# ...                 ...                   ...                  ...
# 1206                174                    40                   76
# 1207                251                    70                  130
# 1208                287                    95                  175
# 1209                243                    85                  157
# 1210                309                    95                  175
#
#       Special Defense Max  Speed Base  Speed Min  Speed Max
# 0                     295          60        112        240
# 1                     339          30         58        174
# 2                     229          90        166        306
# 3                     240          75        139        273
# 4                     240         115        211        361
# ...                   ...         ...        ...        ...
# 1206                  196          55        103        229
# 1207                  262          58        108        236
# 1208                  317          95        175        317
# 1209                  295         115        211        361
# 1210                  317          85        157        295
#
# [1211 rows x 32 columns]
#
# Column names output
# Index(['Pokemon', 'Type', 'Species', 'Height', 'Weight', 'Abilities',
#        'EV Yield', 'Catch Rate', 'Base Friendship', 'Base Exp', 'Growth Rate',
#        'Egg Groups', 'Gender', 'Egg Cycles', 'HP Base', 'HP Min', 'HP Max',
#        'Attack Base', 'Attack Min', 'Attack Max', 'Defense Base',
#        'Defense Min', 'Defense Max', 'Special Attack Base',
#        'Special Attack Min', 'Special Attack Max', 'Special Defense Base',
#        'Special Defense Min', 'Special Defense Max', 'Speed Base', 'Speed Min',
#        'Speed Max'],
#       dtype='object')
#
# Number of missing values
# Pokemon                 0
# Type                    0
# Species                 0
# Height                  0
# Weight                  0
# Abilities               0
# EV Yield                0
# Catch Rate              0
# Base Friendship         0
# Base Exp                0
# Growth Rate             0
# Egg Groups              0
# Gender                  0
# Egg Cycles              0
# HP Base                 0
# HP Min                  0
# HP Max                  0
# Attack Base             0
# Attack Min              0
# Attack Max              0
# Defense Base            0
# Defense Min             0
# Defense Max             0
# Special Attack Base     0
# Special Attack Min      0
# Special Attack Max      0
# Special Defense Base    0
# Special Defense Min     0
# Special Defense Max     0
# Speed Base              0
# Speed Min               0
# Speed Max               0
# dtype: int64
#
# Number of duplicate rows: 0

# %%
# Clean data and convert to numeric format
values_df['Height'] = values_df['Height'].str.extract(r'(\d+\.\d+)').astype(float)
values_df['Weight'] = values_df['Weight'].str.extract(r'(\d+\.\d+)').astype(float)
values_df['HP Base'] = values_df['HP Base'].astype(float)


# Sort by the 'Height' column
values_df.sort_values(by=['Height', 'Weight', 'HP Base'], inplace=True)

# Show results
print(values_df.head())


print('Feature statistics')
print(values_df.describe())

print('\nFirst 10 table values')
print(values_df.head(10))
# Out:
#                      Pokemon        Type               Species  Height  \
# 335                  Flabébé       Fairy  Single Bloom Pokémon     0.1
# 382  Gimmighoul Roaming Form       Ghost   Coin Hunter Pokémon     0.1
# 212                 Cutiefly  Bug, Fairy       Bee Fly Pokémon     0.1
# 941                 Sinistea       Ghost     Black Tea Pokémon     0.1
# 185                   Comfey       Fairy   Posy Picker Pokémon     0.1
#
#      Weight                                          Abilities   EV Yield  \
# 335     0.1         1. Flower Veil, Symbiosis (hidden ability)  1 Sp. Def
# 382     0.1                                        1. Run Away  1 Sp. Atk
# 212     0.2  1. Honey Gather, 2. Shield Dust, Sweet Veil (h...    1 Speed
# 941     0.2        1. Weak Armor, Cursed Body (hidden ability)  1 Sp. Atk
# 185     0.3  1. Flower Veil, 2. Triage, Natural Cure (hidde...  2 Sp. Def
#
#                              Catch Rate Base Friendship Base Exp  ...  \
# 335  225 (29.4% with PokéBall, full HP)     50 (normal)       61  ...
# 382    45 (5.9% with PokéBall, full HP)     50 (normal)       60  ...
# 212  190 (24.8% with PokéBall, full HP)     50 (normal)       61  ...
# 941  120 (15.7% with PokéBall, full HP)     50 (normal)       62  ...
# 185    60 (7.8% with PokéBall, full HP)     50 (normal)      170  ...
#
#     Defense Max Special Attack Base Special Attack Min Special Attack Max  \
# 335         194                  61                114                243
# 382         163                  75                139                273
# 212         196                  55                103                229
# 941         207                  74                137                271
# 185         306                  82                152                289
#
#      Special Defense Base  Special Defense Min  Special Defense Max  \
# 335                    79                  146                  282
# 382                    45                   85                  207
# 212                    40                   76                  196
# 941                    54                  101                  227
# 185                   110                  202                  350
#
#      Speed Base  Speed Min  Speed Max
# 335          42         80        201
# 382          80        148        284
# 212          84        155        293
# 941          50         94        218
# 185         100        184        328
#
# [5 rows x 32 columns]
# Feature statistics
#             Height       Weight      HP Base       HP Min       HP Max  \
# count  1211.000000  1211.000000  1211.000000  1211.000000  1211.000000
# mean      1.288522    71.589678    71.071016   252.050372   345.972750
# std       1.360096   125.689542    26.413587    53.165747    53.599433
# min       0.100000     0.100000     1.000000     1.000000     1.000000
# 25%       0.600000     8.950000    52.000000   214.000000   308.000000
# 50%       1.000000    30.000000    70.000000   250.000000   344.000000
# 75%       1.600000    75.550000    85.000000   280.000000   374.000000
# max      20.000000   950.000000   255.000000   620.000000   714.000000
#
#        Attack Base   Attack Min  Attack Max  Defense Base  Defense Min  \
# count  1211.000000  1211.000000  1211.00000   1211.000000  1211.000000
# mean     81.069364   149.924030   286.47564     74.723369   138.500413
# std      31.908756    57.445245    70.19842     30.224755    54.412769
# min       5.000000    13.000000   119.00000      5.000000    13.000000
# 25%      57.000000   107.000000   234.00000     52.000000    98.000000
# 50%      80.000000   148.000000   284.00000     70.000000   130.000000
# 75%     100.000000   184.000000   328.00000     90.500000   167.000000
# max     190.000000   346.000000   526.00000    230.000000   418.000000
#
#        Defense Max  Special Attack Base  Special Attack Min  \
# count  1211.000000          1211.000000         1211.000000
# mean    272.502890            73.127168          135.620149
# std      66.496907            32.663782           58.801510
# min     119.000000            10.000000           22.000000
# 25%     223.000000            50.000000           94.000000
# 50%     262.000000            65.000000          121.000000
# 75%     307.500000            95.000000          175.000000
# max     614.000000           194.000000          353.000000
#
#        Special Attack Max  Special Defense Base  Special Defense Min  \
# count         1211.000000           1211.000000          1211.000000
# mean           268.988439             72.208092           133.976879
# std             71.876098             27.077629            48.741987
# min            130.000000             20.000000            40.000000
# 25%            218.000000             51.000000            96.000000
# 50%            251.000000             70.000000           130.000000
# 75%            317.000000             90.000000           166.000000
# max            535.000000            230.000000           418.000000
#
#        Special Defense Max   Speed Base    Speed Min    Speed Max
# count          1211.000000  1211.000000  1211.000000  1211.000000
# mean            266.970273    70.003303   130.009909   262.166804
# std              59.572408    30.140333    54.256826    66.335401
# min             152.000000     5.000000    13.000000   119.000000
# 25%             221.000000    45.000000    85.000000   207.000000
# 50%             262.000000    68.000000   126.000000   258.000000
# 75%             306.000000    91.000000   168.000000   309.000000
# max             614.000000   200.000000   364.000000   548.000000
#
# First 10 table values
#                       Pokemon           Type               Species  Height  \
# 335                   Flabébé          Fairy  Single Bloom Pokémon     0.1
# 382   Gimmighoul Roaming Form          Ghost   Coin Hunter Pokémon     0.1
# 212                  Cutiefly     Bug, Fairy       Bee Fly Pokémon     0.1
# 941                  Sinistea          Ghost     Black Tea Pokémon     0.1
# 185                    Comfey          Fairy   Posy Picker Pokémon     0.1
# 507                    Joltik  Bug, Electric     Attaching Pokémon     0.1
# 793              Poltchageist   Grass, Ghost        Matcha Pokémon     0.1
# 193                    Cosmog        Psychic        Nebula Pokémon     0.2
# 1098                   Tynamo       Electric       EleFish Pokémon     0.2
# 659                   Milcery          Fairy         Cream Pokémon     0.2
#
#       Weight                                          Abilities   EV Yield  \
# 335      0.1         1. Flower Veil, Symbiosis (hidden ability)  1 Sp. Def
# 382      0.1                                        1. Run Away  1 Sp. Atk
# 212      0.2  1. Honey Gather, 2. Shield Dust, Sweet Veil (h...    1 Speed
# 941      0.2        1. Weak Armor, Cursed Body (hidden ability)  1 Sp. Atk
# 185      0.3  1. Flower Veil, 2. Triage, Natural Cure (hidde...  2 Sp. Def
# 507      0.6  1. Compound Eyes, 2. Unnerve, Swarm (hidden ab...    1 Speed
# 793      1.1         1. Hospitality, Heatproof (hidden ability)  1 Sp. Atk
# 193      0.1                                         1. Unaware       1 HP
# 1098     0.3                                        1. Levitate    1 Speed
# 659      0.3         1. Sweet Veil, Aroma Veil (hidden ability)  1 Sp. Def
#
#                               Catch Rate        Base Friendship Base Exp  ...  \
# 335   225 (29.4% with PokéBall, full HP)            50 (normal)       61  ...
# 382     45 (5.9% with PokéBall, full HP)            50 (normal)       60  ...
# 212   190 (24.8% with PokéBall, full HP)            50 (normal)       61  ...
# 941   120 (15.7% with PokéBall, full HP)            50 (normal)       62  ...
# 185     60 (7.8% with PokéBall, full HP)            50 (normal)      170  ...
# 507   190 (24.8% with PokéBall, full HP)            50 (normal)       64  ...
# 793   120 (15.7% with PokéBall, full HP)                      —        —  ...
# 193     45 (5.9% with PokéBall, full HP)  0 (lower than normal)       40  ...
# 1098  190 (24.8% with PokéBall, full HP)            50 (normal)       55  ...
# 659   200 (26.1% with PokéBall, full HP)            50 (normal)       54  ...
#
#      Defense Max Special Attack Base Special Attack Min Special Attack Max  \
# 335          194                  61                114                243
# 382          163                  75                139                273
# 212          196                  55                103                229
# 941          207                  74                137                271
# 185          306                  82                152                289
# 507          218                  57                107                234
# 793          207                  74                137                271
# 193          177                  29                 56                172
# 1098         196                  45                 85                207
# 659          196                  50                 94                218
#
#       Special Defense Base  Special Defense Min  Special Defense Max  \
# 335                     79                  146                  282
# 382                     45                   85                  207
# 212                     40                   76                  196
# 941                     54                  101                  227
# 185                    110                  202                  350
# 507                     50                   94                  218
# 793                     54                  101                  227
# 193                     31                   60                  177
# 1098                    40                   76                  196
# 659                     61                  114                  243
#
#       Speed Base  Speed Min  Speed Max
# 335           42         80        201
# 382           80        148        284
# 212           84        155        293
# 941           50         94        218
# 185          100        184        328
# 507           65        121        251
# 793           50         94        218
# 193           37         71        190
# 1098          60        112        240
# 659           34         65        183
#
# [10 rows x 32 columns]

# %%
import numpy as np

values_arr_Height = np.array(values_df)[:, 3]
values_arr_Weight = np.array(values_df)[:, 4]
values_arr_HP_Base = np.array(values_df)[:, 14]

print('Array data output')
print(values_arr_Height)
# Out:
# Array data output
# [0.1 0.1 0.1 ... 12.0 14.5 20.0]

# %%
import matplotlib
import matplotlib.pyplot as plt
from pylab import plot

matplotlib.style.use('ggplot')


plt.figure()

x = np.linspace(values_arr_Height[0], values_arr_Height[values_arr_Height.size - 1], values_arr_Height.size)

plt.plot(x, values_arr_Height,  'g', label='Height')
#plt.plot(x, values_arr_Weight,  'b', label='Weight')
#plt.plot(x, values_arr_HP_Base, 'r', label='HP Base')

plt.legend()
plt.xlabel('Height')
plt.ylabel('Values')
plt.title('Height and Average HP Base Comparison')

plt.show()
